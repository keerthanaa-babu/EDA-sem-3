# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanaa-babu/EDA-sem-3/blob/main/EDA_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/Suicide data.csv')

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
df.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df.shape
# Out:
# (27820, 12)

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                object
# year                    int64
# sex                    object
# age                    object
# suicides_no             int64
# population              int64
# suicides/100k pop     float64
# country-year           object
# HDI for year          float64
#  gdp_for_year ($)      object
# gdp_per_capita ($)      int64
# generation             object
# dtype: object

# %%
df.isnull().mean()*100
# Out:
# country                0.000000
# year                   0.000000
# sex                    0.000000
# age                    0.000000
# suicides_no            0.000000
# population             0.000000
# suicides/100k pop      0.000000
# country-year           0.000000
# HDI for year          69.935298
#  gdp_for_year ($)      0.000000
# gdp_per_capita ($)     0.000000
# generation             0.000000
# dtype: float64

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
df.describe(include='all')
# Out:
#         country          year    sex          age   suicides_no    population  \
# count     27820  27820.000000  27820        27820  27820.000000  2.782000e+04
# unique      101           NaN      2            6           NaN           NaN
# top     Austria           NaN   male  15-24 years           NaN           NaN
# freq        382           NaN  13910         4642           NaN           NaN
# mean        NaN   2001.258375    NaN          NaN    242.574407  1.844794e+06
# std         NaN      8.469055    NaN          NaN    902.047917  3.911779e+06
# min         NaN   1985.000000    NaN          NaN      0.000000  2.780000e+02
# 25%         NaN   1995.000000    NaN          NaN      3.000000  9.749850e+04
# 50%         NaN   2002.000000    NaN          NaN     25.000000  4.301500e+05
# 75%         NaN   2008.000000    NaN          NaN    131.000000  1.486143e+06
# max         NaN   2016.000000    NaN          NaN  22338.000000  4.380521e+07
#
# ...

# %%
df.sample(5)
# Out:
#                    country  year     sex          age  suicides_no  \
# 25632  Trinidad and Tobago  2011  female  55-74 years            4
# 24911          Switzerland  2010    male  15-24 years           47
# 5862              Colombia  2003  female   5-14 years           48
# 13927           Kazakhstan  2005  female   5-14 years           24
# 5241                Canada  2012    male  55-74 years          770
#
#        population  suicides/100k pop             country-year  HDI for year  \
# 25632      105486               3.79  Trinidad and Tobago2011         0.767
# 24911      472649               9.94          Switzerland2010         0.924
# 5862      4175544               1.15             Colombia2003           NaN
# 13927     1219019               1.97           Kazakhstan2005         0.746
# 5241      3586361              21.47               Canada2012         0.910
#
#        gdp_for_year ($)   gdp_per_capita ($)  generation
# ...

# %%
df.notnull().sum()
# Out:
# country               27820
# year                  27820
# sex                   27820
# age                   27820
# suicides_no           27820
# population            27820
# suicides/100k pop     27820
# country-year          27820
# HDI for year           8364
#  gdp_for_year ($)     27820
# gdp_per_capita ($)    27820
# generation            27820
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['country']
# Out:
# 0           Albania
# 1           Albania
# 2           Albania
# 3           Albania
# 4           Albania
#             ...
# 27815    Uzbekistan
# 27816    Uzbekistan
# 27817    Uzbekistan
# 27818    Uzbekistan
# 27819    Uzbekistan
# Name: country, Length: 27820, dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# year                  2.001258e+03
# suicides_no           2.425744e+02
# population            1.844794e+06
# suicides/100k pop     1.281610e+01
# HDI for year          7.766011e-01
# gdp_per_capita ($)    1.686646e+04
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# year                    2002.000
# suicides_no               25.000
# population            430150.000
# suicides/100k pop          5.990
# HDI for year               0.779
# gdp_per_capita ($)      9372.000
# dtype: float64

# %%
df.mode()
# Out:
#           country    year     sex          age  suicides_no  population  \
# 0         Austria  2009.0  female  15-24 years          0.0     24000.0
# 1         Iceland     NaN    male  25-34 years          NaN         NaN
# 2       Mauritius     NaN     NaN  35-54 years          NaN         NaN
# 3     Netherlands     NaN     NaN  55-74 years          NaN         NaN
# 4             NaN     NaN     NaN    75+ years          NaN         NaN
# ...           ...     ...     ...          ...          ...         ...
# 2300          NaN     NaN     NaN          NaN          NaN         NaN
# 2301          NaN     NaN     NaN          NaN          NaN         NaN
# 2302          NaN     NaN     NaN          NaN          NaN         NaN
# 2303          NaN     NaN     NaN          NaN          NaN         NaN
# 2304          NaN     NaN     NaN          NaN          NaN         NaN
#
#       suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.std(numeric_only=True)
# Out:
# year                  8.469055e+00
# suicides_no           9.020479e+02
# population            3.911779e+06
# suicides/100k pop     1.896151e+01
# HDI for year          9.336671e-02
# gdp_per_capita ($)    1.888758e+04
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# year                  7.172489e+01
# suicides_no           8.136904e+05
# population            1.530202e+13
# suicides/100k pop     3.595389e+02
# HDI for year          8.717342e-03
# gdp_per_capita ($)    3.567405e+08
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# year                  1985.000
# suicides_no              0.000
# population             278.000
# suicides/100k pop        0.000
# HDI for year             0.483
# gdp_per_capita ($)     251.000
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# year                  2.016000e+03
# suicides_no           2.233800e+04
# population            4.380521e+07
# suicides/100k pop     2.249700e+02
# HDI for year          9.440000e-01
# gdp_per_capita ($)    1.263520e+05
# dtype: float64

# %%
df[['country','year']]
# Out:
#           country  year
# 0         Albania  1987
# 1         Albania  1987
# 2         Albania  1987
# 3         Albania  1987
# 4         Albania  1987
# ...           ...   ...
# 27815  Uzbekistan  2014
# 27816  Uzbekistan  2014
# 27817  Uzbekistan  2014
# 27818  Uzbekistan  2014
# 27819  Uzbekistan  2014
#
# [27820 rows x 2 columns]

# %%
df.loc[10]
# Out:
# country                       Albania
# year                             1987
# sex                            female
# age                       55-74 years
# suicides_no                         0
# population                     144600
# suicides/100k pop                 0.0
# country-year              Albania1987
# HDI for year                      NaN
#  gdp_for_year ($)       2,156,624,900
# gdp_per_capita ($)                796
# generation            G.I. Generation
# Name: 10, dtype: object

# %%
df.iloc[10]
# Out:
# country                       Albania
# year                             1987
# sex                            female
# age                       55-74 years
# suicides_no                         0
# population                     144600
# suicides/100k pop                 0.0
# country-year              Albania1987
# HDI for year                      NaN
#  gdp_for_year ($)       2,156,624,900
# gdp_per_capita ($)                796
# generation            G.I. Generation
# Name: 10, dtype: object

# %%
df.iloc[5:15]
# Out:
#     country  year     sex          age  suicides_no  population  \
# 5   Albania  1987  female    75+ years            1       35600
# 6   Albania  1987  female  35-54 years            6      278800
# 7   Albania  1987  female  25-34 years            4      257200
# 8   Albania  1987    male  55-74 years            1      137500
# 9   Albania  1987  female   5-14 years            0      311000
# 10  Albania  1987  female  55-74 years            0      144600
# 11  Albania  1987    male   5-14 years            0      338200
# 12  Albania  1988  female    75+ years            2       36400
# 13  Albania  1988    male  15-24 years           17      319200
# 14  Albania  1988    male    75+ years            1       22300
#
#     suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 5                2.81  Albania1987           NaN      2,156,624,900
# 6                2.15  Albania1987           NaN      2,156,624,900
# ...

# %%
df[df['sex']=='male']
# Out:
#           country  year   sex          age  suicides_no  population  \
# 0         Albania  1987  male  15-24 years           21      312900
# 1         Albania  1987  male  35-54 years           16      308000
# 3         Albania  1987  male    75+ years            1       21800
# 4         Albania  1987  male  25-34 years            9      274300
# 8         Albania  1987  male  55-74 years            1      137500
# ...           ...   ...   ...          ...          ...         ...
# 27809  Uzbekistan  2014  male  25-34 years          318     2739150
# 27811  Uzbekistan  2014  male  55-74 years          144     1271111
# 27812  Uzbekistan  2014  male  15-24 years          347     3126905
# 27813  Uzbekistan  2014  male    75+ years           17      224995
# 27817  Uzbekistan  2014  male   5-14 years           60     2762158
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 0                   6.71     Albania1987           NaN      2,156,624,900
# ...

# %%
df[(df['year']>2000) & (df['sex']=='female')]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 147       Albania  2001  female    75+ years            2       47254
# 149       Albania  2001  female  15-24 years            9      271359
# 150       Albania  2001  female  35-54 years           12      370191
# 152       Albania  2001  female  55-74 years            6      189799
# 154       Albania  2001  female  25-34 years            4      222771
# ...           ...   ...     ...          ...          ...         ...
# 27814  Uzbekistan  2014  female  25-34 years          162     2735238
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.sort_values('suicides_no')
# Out:
#                   country  year     sex          age  suicides_no  population  \
# 33                Albania  1989  female   5-14 years            0      321900
# 34                Albania  1989  female    75+ years            0       37000
# 11684             Iceland  1985  female    75+ years            0        6100
# 11685             Iceland  1985    male   5-14 years            0       21400
# 22315          Seychelles  2008    male    75+ years            0        1019
# ...                   ...   ...     ...          ...          ...         ...
# 21057  Russian Federation  1999    male  35-54 years        20705    21016400
# 21068  Russian Federation  2000    male  35-54 years        21063    21378098
# 21080  Russian Federation  2001    male  35-54 years        21262    21476420
# 21008  Russian Federation  1995    male  35-54 years        21706    19249600
# 20996  Russian Federation  1994    male  35-54 years        22338    19044200
#
# ...

# %%
df.sort_values('suicides_no',ascending=False)
# Out:
#                   country  year     sex          age  suicides_no  population  \
# 20996  Russian Federation  1994    male  35-54 years        22338    19044200
# 21008  Russian Federation  1995    male  35-54 years        21706    19249600
# 21080  Russian Federation  2001    male  35-54 years        21262    21476420
# 21068  Russian Federation  2000    male  35-54 years        21063    21378098
# 21057  Russian Federation  1999    male  35-54 years        20705    21016400
# ...                   ...   ...     ...          ...          ...         ...
# 11169              Guyana  1996  female   5-14 years            0       85353
# 11135              Guyana  1993    male    75+ years            0        4112
# 11134              Guyana  1993    male   5-14 years            0       88194
# 11133              Guyana  1993  female    75+ years            0        5036
# 11                Albania  1987    male   5-14 years            0      338200
#
# ...

# %%
df.sort_values(['country','year'])
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df['Suicide Rate']=(df['suicides_no']/df['population'])*100000

# %%
df.rename(columns={'Suicide Rate':'Suicide_Rate'},inplace=True)

# %%
df['GDP Category']=df['gdp_per_capita ($)'].apply(lambda x:'High' if x>20000 else 'Low')

# %%
df['sex'].replace({'male':'M','female':'F'})
# Out:
# 0        M
# 1        M
# 2        F
# 3        M
# 4        M
#         ..
# 27815    F
# 27816    F
# 27817    M
# 27818    F
# 27819    F
# Name: sex, Length: 27820, dtype: object

# %%
df['country'].value_counts()
# Out:
# country
# Austria                   382
# Mauritius                 382
# Netherlands               382
# Iceland                   382
# Brazil                    372
#                          ...
# Bosnia and Herzegovina     24
# Dominica                   12
# Cabo Verde                 12
# Macau                      12
# Mongolia                   10
# Name: count, Length: 101, dtype: int64

# %%
df['country'].unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
df['country'].nunique()
# Out:
# 101

# %%
df.groupby('country')['suicides_no'].sum()
# Out:
# country
# Albania                    1970
# Antigua and Barbuda          11
# Argentina                 82219
# Armenia                    1905
# Aruba                       101
#                          ...
# United Arab Emirates        622
# United Kingdom           136805
# United States           1034013
# Uruguay                   13138
# Uzbekistan                34803
# Name: suicides_no, Length: 101, dtype: int64

# %%
pd.pivot_table(df,values='suicides_no',index='country',columns='sex',aggfunc='sum')
# Out:
# sex                   female    male
# country
# Albania                  693    1277
# Antigua and Barbuda        1      10
# Argentina              18326   63893
# Armenia                  495    1410
# Aruba                     17      84
# ...                      ...     ...
# United Arab Emirates      98     524
# United Kingdom         32687  104118
# United States         213797  820216
# Uruguay                 2820   10318
# Uzbekistan              9260   25543
#
# [101 rows x 2 columns]

# %%
df1=df.iloc[:5000]
df2=df.iloc[5000:]
new_df=pd.concat([df1,df2])

# %%
multi=df.set_index(['country','year'])
multi.stack()
# Out:
# country     year
# Albania     1987  sex                             male
#                   age                      15-24 years
#                   suicides_no                       21
#                   population                    312900
#                   suicides/100k pop               6.71
#                                              ...
# Uzbekistan  2014   gdp_for_year ($)     63,067,077,179
#                   gdp_per_capita ($)              2309
#                   generation                   Boomers
#                   Suicide_Rate                1.459413
#                   GDP Category                     Low
# Length: 314384, dtype: object

# %%
multi.reset_index()
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.set_index('country')
# Out:
#             year     sex          age  suicides_no  population  \
# country
# Albania     1987    male  15-24 years           21      312900
# Albania     1987    male  35-54 years           16      308000
# Albania     1987  female  15-24 years           14      289700
# Albania     1987    male    75+ years            1       21800
# Albania     1987    male  25-34 years            9      274300
# ...          ...     ...          ...          ...         ...
# Uzbekistan  2014  female  35-54 years          107     3620833
# Uzbekistan  2014  female    75+ years            9      348465
# Uzbekistan  2014    male   5-14 years           60     2762158
# Uzbekistan  2014  female   5-14 years           44     2631600
# Uzbekistan  2014  female  55-74 years           21     1438935
#
#             suicides/100k pop    country-year  HDI for year  \
# country
# Albania                  6.71     Albania1987           NaN
# Albania                  5.19     Albania1987           NaN
# ...

# %%
df['suicides_no'].rank(ascending=False)
# Out:
# 0        14503.0
# 1        15555.5
# 2        16019.5
# 3        22770.0
# 4        17362.0
#           ...
# 27815     7770.0
# 27816    17362.0
# 27817    10354.0
# 27818    11606.0
# 27819    14503.0
# Name: suicides_no, Length: 27820, dtype: float64

# %%
df.nlargest(10,'suicides_no')
# Out:
#                   country  year   sex          age  suicides_no  population  \
# 20996  Russian Federation  1994  male  35-54 years        22338    19044200
# 21008  Russian Federation  1995  male  35-54 years        21706    19249600
# 21080  Russian Federation  2001  male  35-54 years        21262    21476420
# 21068  Russian Federation  2000  male  35-54 years        21063    21378098
# 21057  Russian Federation  1999  male  35-54 years        20705    21016400
# 21020  Russian Federation  1996  male  35-54 years        20562    19507100
# 20984  Russian Federation  1993  male  35-54 years        20256    18908000
# 21092  Russian Federation  2002  male  35-54 years        20119    21320535
# 21033  Russian Federation  1997  male  35-54 years        18973    19913400
# 21105  Russian Federation  2003  male  35-54 years        18681    21007346
#
#        suicides/100k pop            country-year  HDI for year  \
# 20996             117.30  Russian Federation1994           NaN
# ...

# %%
df.nsmallest(10,'suicides_no')
# Out:
#     country  year     sex          age  suicides_no  population  \
# 9   Albania  1987  female   5-14 years            0      311000
# 10  Albania  1987  female  55-74 years            0      144600
# 11  Albania  1987    male   5-14 years            0      338200
# 22  Albania  1988  female   5-14 years            0      317200
# 23  Albania  1988    male   5-14 years            0      345000
# 33  Albania  1989  female   5-14 years            0      321900
# 34  Albania  1989  female    75+ years            0       37000
# 35  Albania  1989    male   5-14 years            0      349700
# 44  Albania  1992  female   5-14 years            0      336700
# 45  Albania  1992  female    75+ years            0       38700
#
#     suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 9                 0.0  Albania1987           NaN      2,156,624,900
# 10                0.0  Albania1987           NaN      2,156,624,900
# ...

# %%
df.memory_usage()
# Out:
# Index                    132
# country               222560
# year                  222560
# sex                   222560
# age                   222560
# suicides_no           222560
# population            222560
# suicides/100k pop     222560
# country-year          222560
# HDI for year          222560
#  gdp_for_year ($)     222560
# gdp_per_capita ($)    222560
# generation            222560
# Suicide_Rate          222560
# GDP Category          222560
# dtype: int64

# %%
df.to_csv("processed_suicide_data.csv",index=False)

# %%
df.drop('country-year',axis=1)
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# ...

# %%
df.drop(columns=['country-year'])
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# ...
